# %% [markdown]
# # 非程式題

# %% [markdown]
# 1. 如果 Agent 沒有 planning 能力會有什麼缺點？
#
# 2. planning 在實務應用上會碰到什麼困難？

# %% [markdown]
# # 程式題

# %%
# !pip install --quiet -U langgraph langchain-openai langchain-community tavily-python
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.2/440.2 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 9.8 MB/s eta 0:00:00

# %% [markdown]
# ## 將下列的小工具加進你的 plan-and-execute agent 裡面，使得輸出類似的結果
#
# > 小小 hint：tutorial 照摳就好好🙂，或是大家可以自己寫一些 function 或是找一些外部 api 工具，玩一下看看有什麼新花樣

# %%
import requests
import pandas as pd
from langchain_core.tools import tool

@tool
def getMainBuyAndSale() :
  """台積電股價及其他相關資訊"""
  url = f'https://pchome.megatime.com.tw/stock/sto1/ock4/sid' + '2330' + '.html'
  payloads = {'is_check': '1'}
  resp = requests.request(method='POST', url=url, data=payloads)
  data = pd.read_html(resp.text)

  return data

# %%
import os
from google.colab import userdata

# os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
# os.environ["TAVILY_API_KEY"] = userdata.get('TAVILY_API_KEY')

# %%
from langchain_core.tools import tool
import datetime
from langchain_community.tools.tavily_search import TavilySearchResults

@tool
def get_current_date() -> str:
    """取得現在的日期，格式為 YYYY-MM-DD"""
    return datetime.datetime.now().strftime("%Y-%m-%d")

tools = [
    TavilySearchResults(max_results=3),
    get_current_date
    ]
# Out:
# /tmp/ipython-input-6-1363720969.py:11: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-tavily package and should be used instead. To use it run `pip install -U :class:`~langchain-tavily` and import as `from :class:`~langchain_tavily import TavilySearch``.
#   TavilySearchResults(max_results=3),

# %%
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent

# Choose the LLM that will drive the agent
llm = ChatOpenAI(
    model="gpt-4o-mini-2024-07-18",
    temperature=0
    )

prompt = "你是一個專業等級的任務執行器，用來完美執行任務計劃。"
agent_executor = create_react_agent(
    llm,
    tools,
    prompt=prompt,
    # debug=True
    )

# %%
from IPython.display import Image, display

display(Image(agent_executor.get_graph(xray=True).draw_mermaid_png()))

# %%
agent_executor.invoke({"messages": [("user", "今天幾號？")]})
# Out:
# {'messages': [HumanMessage(content='今天幾號？', additional_kwargs={}, response_metadata={}, id='6c79b021-0bf3-4fc8-ac76-b3c67dddb447'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_F04OJFxkttwPTUrQOcQhu0X6', 'function': {'arguments': '{}', 'name': 'get_current_date'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 132, 'total_tokens': 143, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-BoVgN0VPGwBoDJN6xdjz9L29ubrED', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--a3e14ff9-c75a-4d03-a46e-32232ae7e401-0', tool_calls=[{'name': 'get_current_date', 'args': {}, 'id': 'call_F04OJFxkttwPTUrQOcQhu0X6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 132, 'output_tokens': 11, 'total_tokens': 143, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='2025-07-01', name='get_current_date', id='029409ee-ae50-4a47-9641-43159b42e72b', tool_call_id='call_F04OJFxkttwPTUrQOcQhu0X6'),
#   AIMessage(content='今天是2025年7月1日。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 158, 'total_tokens': 169, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-BoVgNlZvnzhe1vHvB7Eaib4rkBB6s', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ab0fcf68-e22a-4e74-a132-4c23e6a5d2d4-0', usage_metadata={'input_tokens': 158, 'output_tokens': 11, 'total_tokens': 169, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
import operator
from typing import Annotated, List, Tuple
from typing_extensions import TypedDict


class PlanExecute(TypedDict):
    input: str
    plan: List[str] # 待執行的步驟
    past_steps: Annotated[List[Tuple], operator.add] # 執行步驟後的結果
    response: str # 最終的問題回覆結果

# %%
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field

class Plan(BaseModel):
    """未來要遵循的計劃"""

    steps: List[str] = Field(description="不同的步驟，應按順序排列")

planner_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            你是一個專業等級的任務規劃器。
            請根據指定目標，擬定一份簡潔的逐步執行計畫。
            此計畫應包含一系列獨立的任務，每個任務若正確執行，將逐步導向正確的答案。
            請避免加入任何多餘的步驟。
            最終步驟的執行結果即為最終答案。
            請確保每個步驟皆包含完成所需的所有資訊，不得跳過任何必要步驟。
            """,
        ),
        ("placeholder", "{messages}"),
    ]
)

# %%
planner = planner_prompt | ChatOpenAI(
    model="gpt-4.1-2025-04-14",
    temperature=0
).with_structured_output(Plan)

# %%
planner.invoke(
    {
        "messages": [
            ("user", "今天台積電股價如何。")
        ]
    }
)
# Out:
# Plan(steps=['打開可信賴的即時股市資訊網站（如Yahoo奇摩股市、台灣證券交易所官網、鉅亨網等）。', '在搜尋欄輸入「台積電」或股票代號「2330」。', '查找今日台積電（2330）的即時股價資訊。', '記錄並確認今日台積電的最新收盤價或即時價格。', '將查詢到的今日台積電股價作為最終答案。'])

# %%
from typing import Union


class Response(BaseModel):
    """回應使用者的內容"""

    response: str


class Act(BaseModel):
    """要執行的動作"""

    action: Union[Response, Plan] = Field(
        description="要執行的動作： 若要回應使用者，請使用'Response'。"
        "若需進一步使用工具以取得答案，請使用'Plan'。"
    )

replanner_prompt = ChatPromptTemplate.from_template(
    """
    你是一個專業等級的任務規劃器。
    請根據指定目標，擬定一份簡潔的逐步執行計畫。
    此計畫應包含一系列獨立的任務，每個任務若正確執行，將逐步導向正確的答案。
    請避免加入任何多餘的步驟。
    最終步驟的執行結果即為最終答案。
    請確保每個步驟皆包含完成所需的所有資訊，不得跳過任何必要步驟。

    本次任務的目標為：
    {input}

    你原先擬定的計畫為：
    {plan}

    目前已執行的步驟如下：
    {past_steps}

    請根據目前進度，調整後續的執行計畫。
    若已無需進一步步驟，並可直接回應使用者，請進行回應；
    若仍需執行工具或任務取得答案，請補足剩餘計畫。
    請僅列出尚未完成且仍需執行的步驟，勿重複列出已執行的部分。
    """
)

# %%
replanner = replanner_prompt | ChatOpenAI(
    model="gpt-4.1-2025-04-14",
    temperature=0
).with_structured_output(Act)

# %%
from langgraph.graph import END


# 執行計劃中的第一個步驟
async def execute_step(state: PlanExecute):
    plan = state["plan"]
    # 將所有步驟編號整理成文字（用於提示）
    plan_str = "\n".join(f"{i+1}. {step}" for i, step in enumerate(plan))
    task = plan[0] # 抓出第一個尚未執行的步驟
    task_formatted = f"""針對以下計劃：{plan_str}\n\n你的任務是執行 step {1}, {task}."""

    # 呼叫執行器執行該步驟
    agent_response = await agent_executor.ainvoke(
        {"messages": [("user", task_formatted)]}
    )

    # 回傳本次執行結果（步驟與回應）
    return {
        "past_steps": [(task, agent_response["messages"][-1].content)],
    }

# 初始規劃流程
async def plan_step(state: PlanExecute):
    plan = await planner.ainvoke({"messages": [("user", state["input"])]})
    return {"plan": plan.steps}

# 根據已完成的步驟與整體輸入，更新後續步驟或直接產生答案。
async def replan_step(state: PlanExecute):
    output = await replanner.ainvoke(state)

    # 若模型決定可以直接回覆使用者（任務結束），則回傳結果
    if isinstance(output.action, Response):
        return {"response": output.action.response}
    else:
        # 否則更新剩餘計劃
        return {"plan": output.action.steps}

# 檢查是否已經產生最終回應，決定是否結束流程
def should_end(state: PlanExecute):
    if "response" in state and state["response"]:
        return END
    else:
        return "executor"

# %%
from langgraph.graph import StateGraph, START

graph_builder = StateGraph(PlanExecute)

graph_builder.add_node("planner", plan_step) # 新增規劃器節點
graph_builder.add_node("executor", execute_step) # 新增執行器節點
graph_builder.add_node("replanner", replan_step) # 新增重新規劃器節點

graph_builder.add_edge(START, "planner")
graph_builder.add_edge("planner", "executor") # 將規劃器與執行器連接
graph_builder.add_edge("executor", "replanner") # 將執行器與重新規劃器連接

graph_builder.add_conditional_edges(
    "replanner",
    should_end,
    ["executor", END],
)

graph = graph_builder.compile()

# %%
from IPython.display import Image, display

display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %%
from langchain_core.callbacks.base import BaseCallbackHandler

class PrintToolNameHandler(BaseCallbackHandler):
    def on_tool_start(self, serialized_tool: dict, input_str, **kwargs):
        tool_name = serialized_tool.get("name", "<unknown>")
        print(f"[Tool name] {tool_name}")

# %%
config = {"recursion_limit": 50,
          "callbacks":[PrintToolNameHandler()]}
inputs = {"input": "明天適合進場台積電嗎?"}

async for event in graph.astream(inputs, config=config):
    for k, v in event.items():
        if k != "__end__":
            for step in v.keys():
              if step == "plan":
                print(f"[{step}]")
                for idx, action in enumerate(v[step]):
                  print(f"{idx+1}. {action}")

              elif step == "past_steps":
                print(f"[{step}]")
                for action in v[step][0]:
                  print(action)

              else:
                print(f"[{step}]")
                print(v[step])
    print('\n')
# Out:
# [plan]
# 1. 查詢台積電（2330）最新收盤價及近期股價走勢。
# 2. 分析台積電近期的基本面消息（如財報、產業新聞、法說會重點）。
# 3. 檢視台積電技術面指標（如均線、RSI、MACD等）判斷多空趨勢。
# 4. 查詢大盤（加權指數）及半導體產業整體走勢，評估市場氛圍。
# 5. 確認明日有無重大影響台積電的事件（如除息、法說、國際消息）。
# 6. 根據上述資訊，綜合判斷明天是否適合進場台積電。
#
#
# [Tool name] tavily_search_results_json
# [past_steps]
# 查詢台積電（2330）最新收盤價及近期股價走勢。
# ### 台積電（2330）最新收盤價及近期股價走勢
#
# 1. **最新收盤價**：
#    - 台積電的最新收盤價為 **1,085.00** 元，漲幅為 **25.00** 元（2.36%）。
#
# 2. **近期股價走勢**：
#    - 以下是最近幾天的股價走勢：
#      - **2025/07/01**: 收盤 1,085.00
#      - **2025/06/30**: 收盤 1,060.00
#      - **2025/06/29**: 收盤 1,055.00
#      - **2025/06/28**: 收盤 1,050.00
#      - **2025/06/27**: 收盤 1,045.00
#
#    - 近期股價顯示出穩定的上升趨勢，從1,045元上升至1,085元。
#
# ### 參考資料
# - [Yahoo股市 - 台積電(2330.TW)](https://tw.stock.yahoo.com/quote/2330.TW)
# - [鉅亨網 - 台積電(2330)歷史行情](https://www.cnyes.com/twstock/ps_historyprice.aspx)
#
# 這些資訊將有助於後續的分析和決策。
#
#
# [plan]
# 1. 分析台積電近期的基本面消息（如財報、產業新聞、法說會重點）。
# 2. 檢視台積電技術面指標（如均線、RSI、MACD等）判斷多空趨勢。
# 3. 查詢大盤（加權指數）及半導體產業整體走勢，評估市場氛圍。
# 4. 確認明日有無重大影響台積電的事件（如除息、法說、國際消息）。
# 5. 根據上述資訊，綜合判斷明天是否適合進場台積電。
#
#
# [Tool name] tavily_search_results_json
# [past_steps]
# 分析台積電近期的基本面消息（如財報、產業新聞、法說會重點）。
# 以下是台積電近期的基本面消息分析，包括財報、產業新聞及法說會重點：
#
# 1. **法說會重點**：
#    - 台積電於最近的法說會中，董事長魏哲家表示，儘管美國的關稅政策存在不確定性，但目前客戶的行為並未受到影響，對AI需求依然強勁。
#    - 台積電維持2025年的營運展望不變，預計美元營收將成長24%至26%，這一表現將優於晶圓代工業的平均成長水平。
#    - 第2季的營運展望樂觀，預計單季營收將成長13%，高於市場預期的個位數增長。
#
# 2. **財報數據**：
#    - 第1季財報顯示，台積電單季營收為8,392.5億元，毛利率為58.8%，每股盈餘（EPS）為13.94元。
#    - 第2季的展望預測營收在284至292億美元之間，毛利率預計在57%至59%之間。
#
# 3. **產業動態**：
#    - 魏哲家提到，台積電在技術上持續推進，2奈米製程預計將於2025年下半年量產，並且正在擴大在台灣的投資，計劃建置11座晶圓廠及4座先進封裝廠。
#    - 海外設廠的成本較台灣高，預計將對毛利率造成影響，未來5年初期海外廠將影響毛利率約2至3個百分點。
#
# 4. **市場傳言**：
#    - 魏哲家澄清，台積電未與其他公司進行任何合資或技術轉讓的討論，特別是針對與英特爾的合資傳言。
#
# 這些信息顯示台積電在面對外部挑戰時，仍然保持穩健的成長預期，並且在技術創新和市場需求方面持續發展。
#
#
# [plan]
# 1. 檢視台積電技術面指標（如均線、RSI、MACD等）判斷多空趨勢。
# 2. 查詢大盤（加權指數）及半導體產業整體走勢，評估市場氛圍。
# 3. 確認明日有無重大影響台積電的事件（如除息、法說、國際消息）。
# 4. 根據上述資訊，綜合判斷明天是否適合進場台積電。
#
#
# [Tool name] tavily_search_results_json
# [past_steps]
# 檢視台積電技術面指標（如均線、RSI、MACD等）判斷多空趨勢。
# 根據最新的技術面指標，以下是台積電（2330）的分析結果：
#
# 1. **均線**：
#    - 5日均線：1067
#    - 20日均線：1034.65
#    - 60日均線：956.18
#
# 2. **RSI（相對強弱指標）**：
#    - K值（9日）：80.87
#    - D值（9日）：78.21
#
# 3. **MACD（移動平均收斂擴散指標）**：
#    - DIF：25.889
#    - MACD：24.742
#    - DIF-MACD：1.147
#
# ### 判斷多空趨勢：
# - **均線分析**：目前5日均線高於20日和60日均線，顯示短期趨勢強勁，可能呈現上漲趨勢。
# - **RSI分析**：RSI值高於70，顯示目前可能過熱，短期內可能出現回調。
# - **MACD分析**：DIF高於MACD，且差距擴大，顯示上漲動能仍在，但需注意過熱風險。
#
# 綜合以上指標，台積電目前呈現多頭趨勢，但需警惕短期內可能的回調風險。建議在進一步評估市場氛圍及其他影響因素後再做決策。
#
#
# [plan]
# 1. 查詢大盤（加權指數）及半導體產業整體走勢，評估市場氛圍。
# 2. 確認明日有無重大影響台積電的事件（如除息、法說、國際消息）。
# 3. 根據上述資訊，綜合判斷明天是否適合進場台積電。
#
#
# [Tool name] tavily_search_results_json
# [Tool name] tavily_search_results_json
# [past_steps]
# 查詢大盤（加權指數）及半導體產業整體走勢，評估市場氛圍。
# ### 大盤（加權指數）走勢
#
# 1. **加權指數即時行情**：
#    - 成交量：22,553.72
#    - 開盤：22,419.74
#    - 最高：22,730.76
#    - 最低：22,401.58
#    - 昨日收盤：22,256.02
#    - 流動性：-1.34%
#    - [查看詳細](https://tw.stock.yahoo.com/quote/%5ETWII)
#
# 2. **技術分析**：
#    - 提供各種技術指標分析，包括MA、KD、RSI、MACD等，幫助投資者判斷市場走勢。
#    - [查看技術分析](https://tw.stock.yahoo.com/quote/%5ETWII/technical-analysis)
#
# ### 半導體產業整體走勢
#
# 1. **全球半導體市場現況**：
#    - 半導體產業在2020-2021年間因疫情影響需求大增，2021年初期增長超過30%。
#    - 隨著疫情後消費模式的變化，半導體需求仍然強勁，但面臨供應鏈挑戰。
#    - [查看詳細報告](https://zh.oosga.com/industries/semiconductor/)
#
# 2. **2023年半導體產業發展趨勢**：
#    - 預計2023年半導體產業將隨著技術、材料、政策及市場需求的變化而持續發展。
#    - [查看趨勢分析](https://outlook.stpi.niar.org.tw/index/focus-news/4b1141008803288e018803995d0e0122)
#
# ### 總結
# - **市場氛圍**：加權指數顯示出一定的波動性，流動性略有下降，可能反映出市場的不確定性。半導體產業則在需求上仍保持增長，但面臨供應鏈挑戰。
# - **建議**：在進一步確認明日影響台積電的事件之前，需謹慎評估進場時機。
#
#
# [plan]
# 1. 確認明日有無重大影響台積電的事件（如除息、法說、國際消息）。
# 2. 根據所有已蒐集資訊，綜合判斷明天是否適合進場台積電。
#
#
# [Tool name] get_current_date
# [Tool name] tavily_search_results_json
# [Tool name] tavily_search_results_json
# [past_steps]
# 確認明日有無重大影響台積電的事件（如除息、法說、國際消息）。
# 根據最新的資訊，明日（2025年7月2日）有幾個可能影響台積電的重大事件：
#
# 1. **台積電法說會**：台積電將於7月8日舉行法說會，這可能會影響市場對其未來表現的預期，雖然這個事件在明天並不會直接發生，但市場可能會提前反應。
#
# 2. **國際經濟數據發布**：美國將於7月10日發布6月的非農就業數據（NFP）和其他經濟指標（如PMI和CPI），這些數據可能會影響市場情緒，進而影響台積電的股價。
#
# 3. **台積電的公告**：台積電的子公司TSMC Arizona Corporation將於明天進行重要的決策會議，這可能會對其在美國的業務發展產生影響。
#
# 這些事件可能會影響投資者對台積電的看法，因此在考慮進場前，建議密切關注這些消息的發展。
#
#
# [plan]
# 1. 根據所有已蒐集資訊，綜合判斷明天是否適合進場台積電。
#
#
# [Tool name] tavily_search_results_json
# [Tool name] get_current_date
# [past_steps]
# 根據所有已蒐集資訊，綜合判斷明天是否適合進場台積電。
# 根據最新的資訊，台積電在2023年10月的營收表現非常強勁，創下歷史新高。以下是一些關鍵點：
#
# 1. **營收增長**：台積電2023年10月的合併營收約為新台幣2432億元，較9月增加34.8%，較去年同期增長15.7%。這顯示出公司在市場上的強勁需求和增長潛力。
#
# 2. **股價表現**：在公布營收報告後，台積電的股價開盤大漲23元，漲幅達到4.1%，顯示出市場對其業績的正面反應。
#
# 綜合以上資訊，明天進場台積電的時機似乎是合適的，因為公司近期的表現強勁，且市場情緒看起來也相對樂觀。
#
#
# [response]
# 根據目前已執行的所有步驟，已完整蒐集並分析台積電的最新收盤價、基本面、技術面、市場氛圍、產業動態及短期重大事件，並已綜合判斷明天是否適合進場台積電。
#
# 因此，所有必要步驟皆已完成，無需再執行其他任務。
#
# 結論：
#
# 綜合現有資訊，台積電基本面穩健、技術面呈多頭但短線偏熱，市場氛圍尚可，短期無重大利空事件。若您屬於積極型投資人，明天進場台積電具備一定合理性，但需留意短線漲多後的回檔風險。若偏好保守，亦可等待回檔或重大事件明朗後再行進場。
